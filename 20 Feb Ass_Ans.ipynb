# %%
# # Q1

# GET carries request parameter appended in URL string.
# POST carries request parameter in message body 
# which makes it more secure way of transferring data

# %%
# # Q2

# The request module allows you to access the data passed into your Flask application through an HTTP request. 
# The data within a request can be accessed through the request module's properties.

# %%
# # Q3

# A redirect is used in the Flask class to send the user to a particular URL with the status code. conversely, 
# this status code additionally identifies the issue.

# %%
# # Q4

# Templates are files that contain static data as well as placeholders for dynamic data. A template is rendered 
# with specific data to produce a final document. Flask uses the Jinja template library to render templates. 
# In your application, you will use templates to render HTML which will display in the user's browser.

# render_template is a Flask function from the flask. templating package. render_template is used to generate output 
# from a template file based on the Jinja2 engine that is found in the application's templates folder. Note that 
# render_template is typically imported directly from the flask package instead of from flask.

# %%
# Q5

# %% [markdown]
# ![postman_tool.png](attachment:1ef265d4-ae06-49c8-b8b4-b4bd8774f22e.png)
